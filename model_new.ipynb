# %%
# Import the script function that downloads preprocessed fMRI data
from download_abide_preprocessed_dataset import collect_and_download

# %%
# Variables to specify download settings (modify these values as needed)
desired_derivative = 'rois_cc200'  # Derivative of interest (e.g. 'reho')
desired_pipeline = 'cpac'     # Pipeline used to preprocess the data (e.g. 'cpac')    
desired_strategy = 'filt_global'  # Noise-removal strategy used during preprocessing
download_asd_dir = 'abide_preprocessed_dataset/ASD'  # Path to local folder to download files to for ASD data
download_tdc_dir = 'abide_preprocessed_dataset/TDC' # Path to local folder to download files to for controls
desired_diagnosis_asd = 'asd'  # 'asd', 'tdc', or 'both' corresponding to the diagnosis of the participants for whom data should be downloaded
desired_diagnosis_tdc = 'tdc'  # 'asd', 'tdc', or 'both' corresponding to the diagnosis of the participants for whom data should be downloaded

# Call the collect and download routine
collect_and_download(desired_derivative, desired_pipeline, desired_strategy, download_asd_dir, desired_diagnosis_asd)
collect_and_download(desired_derivative, desired_pipeline, desired_strategy, download_tdc_dir, desired_diagnosis_tdc)
# Out:
# Could not find abide_preprocessed_dataset/ASD, creating now...
# Retrieving: abide_preprocessed_dataset/ASD/Outputs/cpac/filt_global/rois_cc200/Pitt_0050004_rois_cc200.1D
# 0.245% percent complete
# Retrieving: abide_preprocessed_dataset/ASD/Outputs/cpac/filt_global/rois_cc200/Pitt_0050005_rois_cc200.1D
# 0.490% percent complete
# Retrieving: abide_preprocessed_dataset/ASD/Outputs/cpac/filt_global/rois_cc200/Pitt_0050006_rois_cc200.1D
# 0.735% percent complete
# Retrieving: abide_preprocessed_dataset/ASD/Outputs/cpac/filt_global/rois_cc200/Pitt_0050007_rois_cc200.1D
# 0.980% percent complete
# Retrieving: abide_preprocessed_dataset/ASD/Outputs/cpac/filt_global/rois_cc200/Pitt_0050008_rois_cc200.1D
# 1.225% percent complete
# Retrieving: abide_preprocessed_dataset/ASD/Outputs/cpac/filt_global/rois_cc200/Pitt_0050009_rois_cc200.1D
# 1.471% percent complete
# Retrieving: abide_preprocessed_dataset/ASD/Outputs/cpac/filt_global/rois_cc200/Pitt_0050010_rois_cc200.1D
# 1.716% percent complete
# Retrieving: abide_preprocessed_dataset/ASD/Outputs/cpac/filt_global/rois_cc200/Pitt_0050011_rois_cc200.1D
# 1.961% percent complete
# Retrieving: abide_preprocessed_dataset/ASD/Outputs/cpac/filt_global/rois_cc200/Pitt_0050012_rois_cc200.1D
# 2.206% percent complete
# Retrieving: abide_preprocessed_dataset/ASD/Outputs/cpac/filt_global/rois_cc200/Pitt_0050014_rois_cc200.1D
# 2.451% percent complete
# Retrieving: abide_preprocessed_dataset/ASD/Outputs/cpac/filt_global/rois_cc200/Pitt_0050015_rois_cc200.1D
# 2.696% percent complete
# Retrieving: abide_preprocessed_dataset/ASD/Outputs/cpac/filt_global/rois_cc200/Pitt_0050016_rois_cc200.1D
# 2.941% percent complete
# Retrieving: abide_preprocessed_dataset/ASD/Outputs/cpac/filt_global/rois_cc200/Pitt_0050020_rois_cc200.1D
# 3.186% percent complete
# Retrieving: abide_preprocessed_dataset/ASD/Outputs/cpac/filt_global/rois_cc200/Pitt_0050022_rois_cc200.1D
# 3.431% percent complete
# Retrieving: abide_preprocessed_dataset/ASD/Outputs/cpac/filt_global/rois_cc200/Pitt_0050023_rois_cc200.1D
# 3.676% percent complete
# Retrieving: abide_preprocessed_dataset/ASD/Outputs/cpac/filt_global/rois_cc200/Pitt_0050024_rois_cc200.1D
# 3.922% percent complete
# Retrieving: abide_preprocessed_dataset/ASD/Outputs/cpac/filt_global/rois_cc200/Pitt_0050025_rois_cc200.1D
# 4.167% percent complete
# Retrieving: abide_preprocessed_dataset/ASD/Outputs/cpac/filt_global/rois_cc200/Pitt_0050027_rois_cc200.1D
# 4.412% percent complete
# Retrieving: abide_preprocessed_dataset/ASD/Outputs/cpac/filt_global/rois_cc200/Pitt_0050029_rois_cc200.1D
# 4.657% percent complete
# Retrieving: abide_preprocessed_dataset/ASD/Outputs/cpac/filt_global/rois_cc200/Pitt_0050055_rois_cc200.1D
# 4.902% percent complete
# Retrieving: abide_preprocessed_dataset/ASD/Outputs/cpac/filt_global/rois_cc200/Pitt_0050056_rois_cc200.1D
# 5.147% percent complete
# Retrieving: abide_preprocessed_dataset/ASD/Outputs/cpac/filt_global/rois_cc200/Pitt_0050057_rois_cc200.1D
# 5.392% percent complete
# Retrieving: abide_preprocessed_dataset/ASD/Outputs/cpac/filt_global/rois_cc200/Olin_0050118_rois_cc200.1D
# 5.637% percent complete
# Retrieving: abide_preprocessed_dataset/ASD/Outputs/cpac/filt_global/rois_cc200/Olin_0050119_rois_cc200.1D
# 5.882% percent complete
# Retrieving: abide_preprocessed_dataset/ASD/Outputs/cpac/filt_global/rois_cc200/Olin_0050121_rois_cc200.1D
# 6.127% percent complete
# Retrieving: abide_preprocessed_dataset/ASD/Outputs/cpac/filt_global/rois_cc200/Olin_0050122_rois_cc200.1D
# 6.373% percent complete
# Retrieving: abide_preprocessed_dataset/ASD/Outputs/cpac/filt_global/rois_cc200/Olin_0050125_rois_cc200.1D
# 6.618% percent complete
# Retrieving: abide_preprocessed_dataset/ASD/Outputs/cpac/filt_global/rois_cc200/Olin_0050127_rois_cc200.1D
# 6.863% percent complete
# Retrieving: abide_preprocessed_dataset/ASD/Outputs/cpac/filt_global/rois_cc200/Olin_0050128_rois_cc200.1D
# 7.108% percent complete
# Retrieving: abide_preprocessed_dataset/ASD/Outputs/cpac/filt_global/rois_cc200/Olin_0050129_rois_cc200.1D
# 7.353% percent complete
# Retrieving: abide_preprocessed_dataset/ASD/Outputs/cpac/filt_global/rois_cc200/Olin_0050130_rois_cc200.1D
# 7.598% percent complete
# Retrieving: abide_preprocessed_dataset/ASD/Outputs/cpac/filt_global/rois_cc200/Olin_0050131_rois_cc200.1D
# 7.843% percent complete
# Retrieving: abide_preprocessed_dataset/ASD/Outputs/cpac/filt_global/rois_cc200/Olin_0050132_rois_cc200.1D
# 8.088% percent complete
# Retrieving: abide_preprocessed_dataset/ASD/Outputs/cpac/filt_global/rois_cc200/Olin_0050133_rois_cc200.1D
# 8.333% percent complete
# Retrieving: abide_preprocessed_dataset/ASD/Outputs/cpac/filt_global/rois_cc200/Olin_0050134_rois_cc200.1D
# 8.578% percent complete
# Retrieving: abide_preprocessed_dataset/ASD/Outputs/cpac/filt_global/rois_cc200/Olin_0050136_rois_cc200.1D
# 8.824% percent complete
# Retrieving: abide_preprocessed_dataset/ASD/Outputs/cpac/filt_global/rois_cc200/OHSU_0050142_rois_cc200.1D
# 9.069% percent complete
# Retrieving: abide_preprocessed_dataset/ASD/Outputs/cpac/filt_global/rois_cc200/OHSU_0050143_rois_cc200.1D
# 9.314% percent complete
# Retrieving: abide_preprocessed_dataset/ASD/Outputs/cpac/filt_global/rois_cc200/OHSU_0050144_rois_cc200.1D
# 9.559% percent complete
# Retrieving: abide_preprocessed_dataset/ASD/Outputs/cpac/filt_global/rois_cc200/OHSU_0050145_rois_cc200.1D
# 9.804% percent complete
# Retrieving: abide_preprocessed_dataset/ASD/Outputs/cpac/filt_global/rois_cc200/OHSU_0050146_rois_cc200.1D
# 10.049% percent complete
# Retrieving: abide_preprocessed_dataset/ASD/Outputs/cpac/filt_global/rois_cc200/OHSU_0050147_rois_cc200.1D
# 10.294% percent complete
# Retrieving: abide_preprocessed_dataset/ASD/Outputs/cpac/filt_global/rois_cc200/OHSU_0050148_rois_cc200.1D
# 10.539% percent complete
# Retrieving: abide_preprocessed_dataset/ASD/Outputs/cpac/filt_global/rois_cc200/OHSU_0050149_rois_cc200.1D
# 10.784% percent complete
# Retrieving: abide_preprocessed_dataset/ASD/Outputs/cpac/filt_global/rois_cc200/OHSU_0050150_rois_cc200.1D
# 11.029% percent complete
# Retrieving: abide_preprocessed_dataset/ASD/Outputs/cpac/filt_global/rois_cc200/OHSU_0050152_rois_cc200.1D
# 11.275% percent complete
# Retrieving: abide_preprocessed_dataset/ASD/Outputs/cpac/filt_global/rois_cc200/OHSU_0050153_rois_cc200.1D
# 11.520% percent complete
# Retrieving: abide_preprocessed_dataset/ASD/Outputs/cpac/filt_global/rois_cc200/OHSU_0050156_rois_cc200.1D
# 11.765% percent complete
# Retrieving: abide_preprocessed_dataset/ASD/Outputs/cpac/filt_global/rois_cc200/SDSU_0050182_rois_cc200.1D
# 12.010% percent complete
# Retrieving: abide_preprocessed_dataset/ASD/Outputs/cpac/filt_global/rois_cc200/SDSU_0050183_rois_cc200.1D
# 12.255% percent complete
# Retrieving: abide_preprocessed_dataset/ASD/Outputs/cpac/filt_global/rois_cc200/SDSU_0050184_rois_cc200.1D
# 12.500% percent complete
# Retrieving: abide_preprocessed_dataset/ASD/Outputs/cpac/filt_global/rois_cc200/SDSU_0
percent complete
# Retrieving: abide_preprocessed_dataset/TDC/Outputs/cpac/filt_global/rois_cc200/MaxMun_c_0051346_rois_cc200.1D
# 91.387% percent complete
# Retrieving: abide_preprocessed_dataset/TDC/Outputs/cpac/filt_global/rois_cc200/MaxMun_c_0051347_rois_cc200.1D
# 91.597% percent complete
# Retrieving: abide_preprocessed_dataset/TDC/Outputs/cpac/filt_global/rois_cc200/MaxMun_d_0051356_rois_cc200.1D
# 91.807% percent complete
# Retrieving: abide_preprocessed_dataset/TDC/Outputs/cpac/filt_global/rois_cc200/MaxMun_d_0051357_rois_cc200.1D
# 92.017% percent complete
# Retrieving: abide_preprocessed_dataset/TDC/Outputs/cpac/filt_global/rois_cc200/MaxMun_d_0051360_rois_cc200.1D
# 92.227% percent complete
# Retrieving: abide_preprocessed_dataset/TDC/Outputs/cpac/filt_global/rois_cc200/MaxMun_a_0051362_rois_cc200.1D
# 92.437% percent complete
# Retrieving: abide_preprocessed_dataset/TDC/Outputs/cpac/filt_global/rois_cc200/MaxMun_a_0051363_rois_cc200.1D
# 92.647% percent complete
# Retrieving: abide_preprocessed_dataset/TDC/Outputs/cpac/filt_global/rois_cc200/MaxMun_a_0051364_rois_cc200.1D
# 92.857% percent complete
# Retrieving: abide_preprocessed_dataset/TDC/Outputs/cpac/filt_global/rois_cc200/MaxMun_a_0051365_rois_cc200.1D
# 93.067% percent complete
# Retrieving: abide_preprocessed_dataset/TDC/Outputs/cpac/filt_global/rois_cc200/MaxMun_a_0051369_rois_cc200.1D
# 93.277% percent complete
# Retrieving: abide_preprocessed_dataset/TDC/Outputs/cpac/filt_global/rois_cc200/MaxMun_a_0051370_rois_cc200.1D
# 93.487% percent complete
# Retrieving: abide_preprocessed_dataset/TDC/Outputs/cpac/filt_global/rois_cc200/MaxMun_a_0051373_rois_cc200.1D
# 93.697% percent complete
# Retrieving: abide_preprocessed_dataset/TDC/Outputs/cpac/filt_global/rois_cc200/Caltech_0051476_rois_cc200.1D
# 93.908% percent complete
# Retrieving: abide_preprocessed_dataset/TDC/Outputs/cpac/filt_global/rois_cc200/Caltech_0051477_rois_cc200.1D
# 94.118% percent complete
# Retrieving: abide_preprocessed_dataset/TDC/Outputs/cpac/filt_global/rois_cc200/Caltech_0051478_rois_cc200.1D
# 94.328% percent complete
# Retrieving: abide_preprocessed_dataset/TDC/Outputs/cpac/filt_global/rois_cc200/Caltech_0051479_rois_cc200.1D
# 94.538% percent complete
# Retrieving: abide_preprocessed_dataset/TDC/Outputs/cpac/filt_global/rois_cc200/Caltech_0051480_rois_cc200.1D
# 94.748% percent complete
# Retrieving: abide_preprocessed_dataset/TDC/Outputs/cpac/filt_global/rois_cc200/Caltech_0051481_rois_cc200.1D
# 94.958% percent complete
# Retrieving: abide_preprocessed_dataset/TDC/Outputs/cpac/filt_global/rois_cc200/Caltech_0051482_rois_cc200.1D
# 95.168% percent complete
# Retrieving: abide_preprocessed_dataset/TDC/Outputs/cpac/filt_global/rois_cc200/Caltech_0051483_rois_cc200.1D
# 95.378% percent complete
# Retrieving: abide_preprocessed_dataset/TDC/Outputs/cpac/filt_global/rois_cc200/Caltech_0051484_rois_cc200.1D
# 95.588% percent complete
# Retrieving: abide_preprocessed_dataset/TDC/Outputs/cpac/filt_global/rois_cc200/Caltech_0051485_rois_cc200.1D
# 95.798% percent complete
# Retrieving: abide_preprocessed_dataset/TDC/Outputs/cpac/filt_global/rois_cc200/Caltech_0051486_rois_cc200.1D
# 96.008% percent complete
# Retrieving: abide_preprocessed_dataset/TDC/Outputs/cpac/filt_global/rois_cc200/Caltech_0051487_rois_cc200.1D
# 96.218% percent complete
# Retrieving: abide_preprocessed_dataset/TDC/Outputs/cpac/filt_global/rois_cc200/Caltech_0051488_rois_cc200.1D
# 96.429% percent complete
# Retrieving: abide_preprocessed_dataset/TDC/Outputs/cpac/filt_global/rois_cc200/Caltech_0051489_rois_cc200.1D
# 96.639% percent complete
# Retrieving: abide_preprocessed_dataset/TDC/Outputs/cpac/filt_global/rois_cc200/Caltech_0051490_rois_cc200.1D
# 96.849% percent complete
# Retrieving: abide_preprocessed_dataset/TDC/Outputs/cpac/filt_global/rois_cc200/Caltech_0051491_rois_cc200.1D
# 97.059% percent complete
# Retrieving: abide_preprocessed_dataset/TDC/Outputs/cpac/filt_global/rois_cc200/Caltech_0051492_rois_cc200.1D
# 97.269% percent complete
# Retrieving: abide_preprocessed_dataset/TDC/Outputs/cpac/filt_global/rois_cc200/Caltech_0051493_rois_cc200.1D
# 97.479% percent complete
# Retrieving: abide_preprocessed_dataset/TDC/Outputs/cpac/filt_global/rois_cc200/SBL_0051557_rois_cc200.1D
# 97.689% percent complete
# Retrieving: abide_preprocessed_dataset/TDC/Outputs/cpac/filt_global/rois_cc200/SBL_0051558_rois_cc200.1D
# 97.899% percent complete
# Retrieving: abide_preprocessed_dataset/TDC/Outputs/cpac/filt_global/rois_cc200/SBL_0051559_rois_cc200.1D
# 98.109% percent complete
# Retrieving: abide_preprocessed_dataset/TDC/Outputs/cpac/filt_global/rois_cc200/SBL_0051560_rois_cc200.1D
# 98.319% percent complete
# Retrieving: abide_preprocessed_dataset/TDC/Outputs/cpac/filt_global/rois_cc200/SBL_0051561_rois_cc200.1D
# 98.529% percent complete
# Retrieving: abide_preprocessed_dataset/TDC/Outputs/cpac/filt_global/rois_cc200/SBL_0051562_rois_cc200.1D
# 98.739% percent complete
# Retrieving: abide_preprocessed_dataset/TDC/Outputs/cpac/filt_global/rois_cc200/SBL_0051563_rois_cc200.1D
# 98.950% percent complete
# Retrieving: abide_preprocessed_dataset/TDC/Outputs/cpac/filt_global/rois_cc200/SBL_0051564_rois_cc200.1D
# 99.160% percent complete
# Retrieving: abide_preprocessed_dataset/TDC/Outputs/cpac/filt_global/rois_cc200/SBL_0051565_rois_cc200.1D
# 99.370% percent complete
# Retrieving: abide_preprocessed_dataset/TDC/Outputs/cpac/filt_global/rois_cc200/SBL_0051566_rois_cc200.1D
# 99.580% percent complete
# Retrieving: abide_preprocessed_dataset/TDC/Outputs/cpac/filt_global/rois_cc200/SBL_0051567_rois_cc200.1D
# 99.790% percent complete
# Retrieving: abide_preprocessed_dataset/TDC/Outputs/cpac/filt_global/rois_cc200/SBL_0051570_rois_cc200.1D
# 100.000% percent complete
# Done!

# %%
# Organizing Features and Labels to input into ML algorithm

# importing necessary files
import os
import numpy as np

def gather_features(data_dir):
    features = []

    for file_name in os.listdir(data_dir):
        subject_path = os.path.join(data_dir, file_name)

        # Check if the file is a timeseries file 
        if file_name.endswith('.1D'):
            # Load the timeseries data 
            timeseries_data = load_timeseries_data(subject_path)

            # Append features
            features.append(timeseries_data)

    features_list = [np.array(feature) for feature in features]    
    return features_list

def load_timeseries_data(file_path):
    # Load timeseries data from the 1D file
    with open(file_path, 'r') as f:
        timeseries = np.loadtxt(f)

    return timeseries

# Define a function for padding time series data
def pad_timeseries_to_length(timeseries, target_length):
    if len(timeseries) >= target_length:
        return timeseries[:target_length]
    else:
        padding = np.zeros((target_length - len(timeseries), timeseries.shape[1]))
        return np.vstack([timeseries, padding])

# Specify the path to the directory containing the downloaded preprocessed data for ASD data
download_asd_dir = 'abide_preprocessed_dataset/ASD/Outputs/cpac/filt_global/rois_cc200'
# Make features and labels arrays for ASD data
features_asd = gather_features(download_asd_dir)
labels_asd = np.ones(len(features_asd)) # Label 1 for ASD, 0 for TDC

# Specify the path to the directory containing the downloaded preprocessed data for TDC data
download_tdc_dir = 'abide_preprocessed_dataset/TDC/Outputs/cpac/filt_global/rois_cc200'
# Make features and labels arrays for TDC data
features_tdc = gather_features(download_tdc_dir)
labels_tdc = np.zeros(len(features_tdc)) # Label 1 for ASD, 0 for TDC

# Concatenate ASD and TDC features 
all_features = []
all_features.extend(features_asd) 
all_features.extend(features_tdc)

# Padding timeseries and # of features for features 
max_length = max(len(ts) for ts in all_features) # Find the maximum length among all timeseries
all_features_padded = [pad_timeseries_to_length(ts, max_length) for ts in all_features] # Pad each time series to the maximum length
all_features = np.array(all_features_padded) # Convert the list of padded arrays to a 2D NumPy array
all_features = all_features.reshape((len(all_features), -1)) # Flatten each time series in all_features to make it a 2D array that is readable for scikit-learn's ML algorithms

# Concatenate ASD and TDC labels
all_labels = np.zeros(len(labels_asd) + len(labels_tdc)) # Create an array of zeros with the total length
all_labels[:len(labels_asd)] = labels_asd # Assign the ASD labels to the first part of the array
all_labels[len(labels_asd):] = labels_tdc # Assign the TDC labels to the remaining part of the array
all_labels = np.array(all_labels)

print("Number of rows in all_features:", len(all_features))
print("Number of rows in all_labels:", len(all_labels))
print("Shape of all_features: ", all_features.shape)
print("Shape of all_labels: ", all_labels.shape)
# Out:
# Number of rows in all_features: 884
# Number of rows in all_labels: 884
# Shape of all_features:  (884, 63200)
# Shape of all_labels:  (884,)

# %%
# Part of scikit-learn library; Support Vector Classification (SVC), a type of SVM used for classification tasks
from sklearn.svm import SVC 

# Function from scikit-learn; splits datasets into training and testing sets
from sklearn.model_selection import train_test_split 

# Function from scikit-learn; computes parameters relating to the model's performance
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

# TRAINING AND TESTING SVM MODEL

# General function for training/testing SVM model
def train_test_svm(X_train, X_test, y_train, y_test):
    # Initialize SVM model
    svm_model = SVC()

    # Train the SVM model
    svm_model.fit(X_train, y_train)

    # Test the SVM model
    y_predictions = svm_model.predict(X_test)

    accuracy = accuracy_score(y_test, y_predictions) # Compute accuracy
    conf_matrix = confusion_matrix(y_test, y_predictions) # Compute confusion matrix
    tn, fp, fn, tp = conf_matrix.ravel() # Extract true positives, false positives, true negatives, and false negatives from confusion matrix
    sensitivity = tp / (tp + fn) # Compute sensitivity (recall)
    specificity = tn / (tn + fp) # Compute specificity
    precision = tp / (tp + fp) # Compute precision
    f1_score = 2 * (precision * sensitivity) / (precision + sensitivity) # Compute F1 score
    class_report = classification_report(y_test, y_predictions)

    return accuracy, conf_matrix, sensitivity, specificity, precision, f1_score, class_report

# Function for training/testing fMRI data with SVM model
def train_test_fMRI_data(fMRI_features, labels):
    # Split the data into training and testing sets
    X_train, X_test, y_train, y_test = train_test_split(fMRI_features, labels, test_size=0.2, random_state=42)

    # Train and test SVM model
    accuracy, conf_matrix, sensitivity, specificity, precision, f1_score, class_report = train_test_svm(X_train, X_test, y_train, y_test)

    print("Accuracy: ", accuracy)
    print("Confusion Matrix: \n", conf_matrix)
    print("Sensitivity: ", sensitivity)
    print("Specificity: ", specificity)
    print("Precision: ", precision)
    print("F1 Score: ", f1_score)
    print("Classification Report: \n", class_report)

# %%
train_test_fMRI_data(all_features, all_labels)
# Out:
# Accuracy:  0.519774011299435
# Confusion Matrix:
#  [[91  0]
#  [85  1]]
# Sensitivity:  0.011627906976744186
# Specificity:  1.0
# Precision:  1.0
# F1 Score:  0.022988505747126436
# Classification Report:
#                precision    recall  f1-score   support
#
#          0.0       0.52      1.00      0.68        91
#          1.0       1.00      0.01      0.02        86
#
#     accuracy                           0.52       177
#    macro avg       0.76      0.51      0.35       177
# weighted avg       0.75      0.52      0.36       177
