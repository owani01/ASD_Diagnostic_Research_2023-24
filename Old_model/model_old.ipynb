# %%
# Import necessary libraries

# Library for XML preprocessing 
import xml.etree.ElementTree as ET 

# Module for interacting w/ operating system, interacting with system environment, etc.
import os 

# Library used to make HTTP requests in Python
import requests 

# Part of Nilearn library; used for neuroimaging image manipulation and analysis
from nilearn import image 

# Part of scikit-learn library; provides tools for data preprocessing
from sklearn.preprocessing import StandardScaler 

# Part of scikit-learn library; provides tools for dimensionality reduction
from sklearn.decomposition import PCA 

# Part of scikit-learn library; Support Vector Classification (SVC), a type of SVM used for classification tasks
from sklearn.svm import SVC 

# Function from scikit-learn; splits datasets into training and testing sets
from sklearn.model_selection import train_test_split 

# Function from scikit-learn; computes accuracy classification score
from sklearn.metrics import accuracy_score 

# Library used for wavelet transform; used for time-frequency analysis on EEG data
# import pywt 

# Library for handling complex arrays & mathematical operations
import numpy as np 

# Module w/ higher-level interface for basic file operations
import shutil

# %%
# DATA COLLECTION (Getting Catalog_XML file of fMRI dataset)

# Specify the path to the XML file
xml_file_path = "ABIDE1_Dataset.xml"   # ABIDE I (fMRI) Dataset

# Read the XML data from the file
with open(xml_file_path, "r") as xml_file:
    # Read the XML content, and remove any leading non-XML characters
    xml_data = xml_file.read().lstrip()

# Parse the XML data
root = ET.fromstring(xml_data)

# %%
# DATA PREPROCESSING (function for fMRI data preprocessing)

def preprocess_fmri_data(fmri_data_path, TR=None):
    # Implement preprocessing steps (motion correction, slice timing correction, etc.)
    
    # Load the fMRI data
    fMRI_data = image.load_img(fmri_data_path)

    # Motion Correction - corrects random motion during scanning
    fMRI_data_corrected = image.smooth_ing(fMRI_data, fwhm=5)

    # Slice Timing Correction - adjusts for time differences between 'slices' of data
    if TR is None:
        # If TR isn't known, use a default TR (in seconds)
        default_TR = 2.0 
        fMRI_data_corrected = image.concat_imgs(
            image.slicetimer.slice_time_corrector(fMRI_data_corrected, TR=default_TR)
        )
    else:
        fMRI_data_corrected = image.concat_imgs(
            image.slicetimer.slice_time_corrector(fMRI_data_corrected, TR=TR))

    # Spatial Smoothing - reduces external noise and enhances signal via a spatial filter
    fMRI_data_smoothed = image.smooth_ing(fMRI_data_corrected, fwhm=8)

    # Intensity Normalization - scales the intensity values to a common scale
    scaler = StandardScaler()
    fMRI_data_normalized = scaler.fit_transform(fMRI_data_smoothed.get_fdata())

    return fMRI_data_normalized

# %%
# DATA PREPROCESSING (function for EEG data preprocessing)

def preprocess_eeg_data(eeg_data):
    # Implement preprocessing steps for EEG data - ???
    pass

# %%
# ?????

def load_your_ROI_masks():
    pass

# %%
# FEATURE EXTRACTION (function for selecting 'key features' from preprocessed data)
# Currently, only for fMRI data (dataset is only fMRI data)

def fMRI_feature_extraction(fMRI_data_normalized): # modify to add EEG_data_normalized as argument
    # Assuming ROIs are defined for fMRI feature extraction - ???
    ROI_masks = load_your_ROI_masks()

    # Extracting mean fMRI signals from ROIs - ???
    fMRI_ROI_signals = []
    for mask in ROI_masks:
        fMRI_ROI_signals.append(image.mean_img(fMRI_data_normalized, mask=mask))
    
    # Perform Time-Frequency Analysis for EEG (e.g., using wavelet transform) - ???
    # Assuming EEG_data is in the shape (channels, time points)
    # Adjust parameters as needed based on your data
    # wavelet_transformed_data = pywt.cwt(eeg_data, scales=np.arange(1, 128), wavelet='cmor')

    # Feature Selection using PCA (for both fMRI and EEG) - ???
    # Assuming you want to reduce dimensionality to 10 components - ???
    pca = PCA(n_components=10)
    fMRI_features_selected = pca.fit_transform(fMRI_ROI_signals)
    # eeg_features_selected = pca.fit_transform(wavelet_transformed_data)

    # Resulting selected features: fMRI_features_selected, eeg_features_selected
    return fMRI_features_selected #, eeg_features_selected

# %%
# TRAINING AND TESTING SVM MODEL

# General function for training/testing SVM model
def train_test_svm(X_train, X_test, y_train, y_test):
    # Initialize SVM model
    svm_model = SVC()

    # Train the SVM model
    svm_model.fit(X_train, y_train)

    # Test the SVM model
    predictions = svm_model.predict(X_test)

    # Calculate accuracy
    accuracy = accuracy_score(y_test, predictions)

    return accuracy

# Function for training/testing fMRI data with SVM model
def train_test_fMRI_data(fMRI_features, labels):
    # Split the data into training and testing sets
    X_train, X_test, y_train, y_test = train_test_split(fMRI_features, labels, test_size=0.1, random_state=42)

    # Train and test SVM model
    accuracy = train_test_svm(X_train, X_test, y_train, y_test)

    return accuracy

# %%
# ALL FUNCTIONALITY DONE IN BATCHES:
# DATA COLLECTION (extracting fMRI data),
# DATA PREPROCESSING & FEATURE SELECTION (using functions),
# TRAINING & TESTING DATA w/ ML ALGORITHM(s) (using functions),
# COMPUTING ACCURACY SCORES

# Directory to save downloaded fMRI datasets
download_dir = "/workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets"
os.makedirs(download_dir, exist_ok=True)

# Navigate to entrySet elements with the ID "RAW"
raw_entry_sets = root.findall('.//cat:entrySet[@ID="RAW"]', namespaces={'cat': 'http://nrg.wustl.edu/catalog'})

# Iterate through RAW entrySets to extract and download fMRI data
for raw_entry_set in raw_entry_sets:
    # Navigate to entries element under the RAW entrySet
    entries_element = raw_entry_set.find('.//cat:entries', namespaces={'cat': 'http://nrg.wustl.edu/catalog'})

    # Navigate to entry elements under the entries element
    entries = entries_element.findall('.//cat:entry', namespaces={'cat': 'http://nrg.wustl.edu/catalog'})

    # Extract subject name from entrySet
    subject_name = raw_entry_set.get('ID')

    # Labels for your SVM model (modify based on your actual labels)
    labels = np.random.randint(0, 2, len(entries))

    # Initialize arrays to store features and labels
    all_features = []
    all_labels = []

    # Iterate through entries and download fMRI data in batches
    for entry in entries:
        # Extract relevant information, such as URI and name
        entry_uri = entry.get('URI')
        entry_name = entry.get('name')

        # Construct a URL based on the extracted URI
        base_url = "https://www.nitrc.org/ir/data"  
        full_url = f"{base_url}{entry_uri}"

        # Download the fMRI files using requests library
        response = requests.get(full_url, stream=True)

        # Specify the directory to save the downloaded files
        base_dir = "/workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets"
        
        # Save the downloaded fMRI files with an informative entry name
        file_name = f"downloaded_files.json"
        save_dir = os.path.join(base_dir, subject_name, entry_name)
        print(f"Base dir: {base_dir}, \n Subject name: {subject_name}, \n Entry name: {entry_name}")
        print(f"save_dir: {save_dir}")
        os.makedirs(save_dir, exist_ok=True)
        file_path = os.path.join(save_dir, file_name)
        print(f"file_path: {file_path}")

        with open(file_path, 'wb') as file:
            for chunk in response.iter_content(chunk_size=128):
                file.write(chunk)

        # Perform preprocessing on the downloaded fMRI data
        #preprocess_fmri_data(file_path)

        # Load the preprocessed fMRI data (modify based on actual data loading)
        #preprocessed_fMRI_data = image.load_img(file_path)

        #fMRI_features = fMRI_feature_extraction(preprocessed_fMRI_data)
        
        # EEG data - gather, preprocess, extract features
        # EEG_data = np.random.rand(EEG_data_shape)
        # preprocess_eeg_data(EEG_data)
        # preprocessed_EEG_data = image.load_img(EEG_data)
        # fMRI_features, EEG_features = feature_extraction(preprocessed_fMRI_data, preprocessed_EEG_data)

        # Append features and labels - ???
        #all_features.append(fMRI_features)
        #all_labels.append(labels)

        # Delete the downloaded and processsed data
        #shutil.rmtree(save_dir)
    

    # Stack features & labels - ???
    #all_features = np.vstack(all_features)
    #all_labels = np.concatenate(all_labels)

    # Train and test SVM model
    #accuracy = train_test_fMRI_data(all_features, all_labels)
# Out:
# Base dir: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets,
#  Subject name: RAW,
#  Entry name: ABIDE/Stanford_51176/Stanford_51176/anat/NIfTI
# save_dir: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets/RAW/ABIDE/Stanford_51176/Stanford_51176/anat/NIfTI
# file_path: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets/RAW/ABIDE/Stanford_51176/Stanford_51176/anat/NIfTI/downloaded_files.json
# Base dir: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets,
#  Subject name: RAW,
#  Entry name: ABIDE/Stanford_51176/Stanford_51176/anat/SNAPSHOTS
# save_dir: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets/RAW/ABIDE/Stanford_51176/Stanford_51176/anat/SNAPSHOTS
# file_path: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets/RAW/ABIDE/Stanford_51176/Stanford_51176/anat/SNAPSHOTS/downloaded_files.json
# Base dir: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets,
#  Subject name: RAW,
#  Entry name: ABIDE/Stanford_51176/Stanford_51176/rest/NIfTI
# save_dir: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets/RAW/ABIDE/Stanford_51176/Stanford_51176/rest/NIfTI
# file_path: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets/RAW/ABIDE/Stanford_51176/Stanford_51176/rest/NIfTI/downloaded_files.json
# Base dir: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets,
#  Subject name: RAW,
#  Entry name: ABIDE/Stanford_51176/Stanford_51176/rest/SNAPSHOTS
# save_dir: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets/RAW/ABIDE/Stanford_51176/Stanford_51176/rest/SNAPSHOTS
# file_path: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets/RAW/ABIDE/Stanford_51176/Stanford_51176/rest/SNAPSHOTS/downloaded_files.json
# Base dir: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets,
#  Subject name: RAW,
#  Entry name: ABIDE/Stanford_51177/Stanford_51177/anat/NIfTI
# save_dir: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets/RAW/ABIDE/Stanford_51177/Stanford_51177/anat/NIfTI
# file_path: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets/RAW/ABIDE/Stanford_51177/Stanford_51177/anat/NIfTI/downloaded_files.json
# Base dir: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets,
#  Subject name: RAW,
#  Entry name: ABIDE/Stanford_51177/Stanford_51177/anat/SNAPSHOTS
# save_dir: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets/RAW/ABIDE/Stanford_51177/Stanford_51177/anat/SNAPSHOTS
# file_path: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets/RAW/ABIDE/Stanford_51177/Stanford_51177/anat/SNAPSHOTS/downloaded_files.json
# Base dir: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets,
#  Subject name: RAW,
#  Entry name: ABIDE/Stanford_51177/Stanford_51177/rest/NIfTI
# save_dir: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets/RAW/ABIDE/Stanford_51177/Stanford_51177/rest/NIfTI
# file_path: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets/RAW/ABIDE/Stanford_51177/Stanford_51177/rest/NIfTI/downloaded_files.json
# Base dir: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets,
#  Subject name: RAW,
#  Entry name: ABIDE/Stanford_51177/Stanford_51177/rest/SNAPSHOTS
# save_dir: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets/RAW/ABIDE/Stanford_51177/Stanford_51177/rest/SNAPSHOTS
# file_path: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets/RAW/ABIDE/Stanford_51177/Stanford_51177/rest/SNAPSHOTS/downloaded_files.json
# Base dir: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets,
#  Subject name: RAW,
#  Entry name: ABIDE/Stanford_51174/Stanford_51174/anat/NIfTI
# save_dir: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets/RAW/ABIDE/Stanford_51174/Stanford_51174/anat/NIfTI
# file_path: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets/RAW/ABIDE/Stanford_51174/Stanford_51174/anat/NIfTI/downloaded_files.json
# Base dir: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets,
#  Subject name: RAW,
#  Entry name: ABIDE/Stanford_51174/Stanford_51174/anat/SNAPSHOTS
# save_dir: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets/RAW/ABIDE/Stanford_51174/Stanford_51174/anat/SNAPSHOTS
# file_path: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets/RAW/ABIDE/Stanford_51174/Stanford_51174/anat/SNAPSHOTS/downloaded_files.json
# Base dir: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets,
#  Subject name: RAW,
#  Entry name: ABIDE/Stanford_51174/Stanford_51174/rest/NIfTI
# save_dir: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets/RAW/ABIDE/Stanford_51174/Stanford_51174/rest/NIfTI
# file_path: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets/RAW/ABIDE/Stanford_51174/Stanford_51174/rest/NIfTI/downloaded_files.json
# Base dir: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets,
#  Subject name: RAW,
#  Entry name: ABIDE/Stanford_51174/Stanford_51174/rest/SNAPSHOTS
# save_dir: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets/RAW/ABIDE/Stanford_51174/Stanford_51174/rest/SNAPSHOTS
# file_path: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets/RAW/ABIDE/Stanford_51174/Stanford_51174/rest/SNAPSHOTS/downloaded_files.json
# Base dir: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets,
#  Subject name: RAW,
#  Entry name: ABIDE/Stanford_51175/Stanford_51175/anat/NIfTI
# save_dir: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets/RAW/ABIDE/Stanford_51175/Stanford_51175/anat/NIfTI
# file_path: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets/RAW/ABIDE/Stanford_51175/Stanford_51175/anat/NIfTI/downloaded_files.json
# Base dir: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets,
#  Subject name: RAW,
#  Entry name: ABIDE/Stanford_51175/Stanford_51175/anat/SNAPSHOTS
# save_dir: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets/RAW/ABIDE/Stanford_51175/Stanford_51175/anat/SNAPSHOTS
# file_path: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets/RAW/ABIDE/Stanford_51175/Stanford_51175/anat/SNAPSHOTS/downloaded_files.json
# Base dir: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets,
#  Subject name: RAW,
#  Entry name: ABIDE/Stanford_51175/Stanford_51175/rest/NIfTI
# save_dir: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets/RAW/ABIDE/Stanford_51175/Stanford_51175/rest/NIfTI
# file_path: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets/RAW/ABIDE/Stanford_51175/Stanford_51175/rest/NIfTI/downloaded_files.json
# Base dir: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets,
#  Subject name: RAW,
#  Entry name: ABIDE/Stanford_51175/Stanford_51175/rest/SNAPSHOTS
# save_dir: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets/RAW/ABIDE/Stanford_51175/Stanford_51175/rest/SNAPSHOTS
# file_path: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets/RAW/ABIDE/Stanford_51175/Stanford_51175/rest/SNAPSHOTS/downloaded_files.json
# Base dir: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets,
#  Subject name: RAW,
#  Entry name: ABIDE/Stanford_51172/Stanford_51172/anat/NIfTI
# save_dir: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets/RAW/ABIDE/Stanford_51172/Stanford_51172/anat/NIfTI
# file_path: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets/RAW/ABIDE/Stanford_51172/Stanford_51172/anat/NIfTI/downloaded_files.json
# Base dir: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets,
#  Subject name: RAW,
#  Entry name: ABIDE/Stanford_51172/Stanford_51172/anat/SNAPSHOTS
# save_dir: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets/RAW/ABIDE/Stanford_51172/Stanford_51172/anat/SNAPSHOTS
# file_path: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets/RAW/ABIDE/Stanford_51172/Stanford_51172/anat/SNAPSHOTS/downloaded_files.json
# Base dir: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets,
#  Subject name: RAW,
#  Entry name: ABIDE/Stanford_51172/Stanford_51172/rest/NIfTI
# save_dir: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets/RAW/ABIDE/Stanford_51172/Stanford_51172/rest/NIfTI
# file_path: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets/RAW/ABIDE/Stanford_51172/Stanford_51172/rest/NIfTI/downloaded_files.json
# Base dir: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets,
#  Subject name: RAW,
#  Entry name: ABIDE/Stanford_51172/Stanford_51172/rest/SNAPSHOTS
# save_dir: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets/RAW/ABIDE/Stanford_51172/Stanford_51172/rest/SNAPSHOTS
# file_path: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets/RAW/ABIDE/Stanford_51172/Stanford_51172/rest/SNAPSHOTS/downloaded_files.json
# Base dir: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets,
#  Subject name: RAW,
#  Entry name: ABIDE/Stanford_51173/Stanford_51173/anat/NIfTI
# save_dir: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets/RAW/ABIDE/Stanford_51173/Stanford_51173/anat/NIfTI
# file_path: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets/RAW/ABIDE/Stanford_51173/Stanford_51173/anat/NIfTI/downloaded_files.json
# Base dir: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets,
#  Subject name: RAW,
#  Entry name: ABIDE/Stanford_51173/Stanford_51173/anat/SNAPSHOTS
# save_dir: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets/RAW/ABIDE/Stanford_51173/Stanford_51173/anat/SNAPSHOTS
# file_path: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets/RAW/ABIDE/Stanford_51173/Stanford_51173/anat/SNAPSHOTS/downloaded_files.json
# Base dir: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets,
#  Subject name: RAW,
#  Entry name: ABIDE/Stanford_51173/Stanford_51173/rest/NIfTI
# save_dir: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets/RAW/ABIDE/Stanford_51173/Stanford_51173/rest/NIfTI
# file_path: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets/RAW/ABIDE/Stanford_51173/Stanford_51173/rest/NIfTI/downloaded_files.json
# Base dir: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets,
#  Subject name: RAW,
#  Entry name: ABIDE/Stanford_51173/Stanford_51173/rest/SNAPSHOTS
# save_dir: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets/RAW/ABIDE/Stanford_51173/Stanford_51173/rest/SNAPSHOTS
# file_path: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets/RAW/ABIDE/Stanford_51173/Stanford_51173/rest/SNAPSHOTS/downloaded_files.json
# Base dir: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets,
#  Subject name: RAW,
#  Entry name: ABIDE/Stanford_51170/Stanford_51170/anat/NIfTI
# save_dir: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets/RAW/ABIDE/Stanford_51170/Stanford_51170/anat/NIfTI
# file_path: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets/RAW/ABIDE/Stanford_51170/Stanford_51170/anat/NIfTI/downloaded_files.json
# Base dir: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets,
#  Subject name: RAW,
#  Entry name: ABIDE/Stanford_51170/Stanford_51170/anat/SNAPSHOTS
# save_dir: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets/RAW/ABIDE/Stanford_51170/Stanford_51170/anat/SNAPSHOTS
# file_path: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets/RAW/ABIDE/Stanford_51170/Stanford_51170/anat/SNAPSHOTS/downloaded_files.json
# Base dir: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets,
#  Subject name: RAW,
#  Entry name: ABIDE/Stanford_51170/Stanford_51170/rest/NIfTI
# save_dir: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets/RAW/ABIDE/Stanford_51170/Stanford_51170/rest/NIfTI
# file_path: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets/RAW/ABIDE/Stanford_51170/Stanford_51170/rest/NIfTI/downloaded_files.json
# Base dir: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets,
#  Subject name: RAW,
#  Entry name: ABIDE/Stanford_51170/Stanford_51170/rest/SNAPSHOTS
# save_dir: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets/RAW/ABIDE/Stanford_51170/Stanford_51170/rest/SNAPSHOTS
# file_path: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets/RAW/ABIDE/Stanford_51170/Stanford_51170/rest/SNAPSHOTS/downloaded_files.json
# Base dir: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets,
#  Subject name: RAW,
#  Entry name: ABIDE/Stanford_51171/Stanford_51171/anat/NIfTI
# save_dir: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets/RAW/ABIDE/Stanford_51171/Stanford_51171/anat/NIfTI
# file_path: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets/RAW/ABIDE/Stanford_51171/Stanford_51171/anat/NIfTI/downloaded_files.json
# Base dir: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets,
#  Subject name: RAW,
#  Entry name: ABIDE/Stanford_51171/Stanford_51171/anat/SNAPSHOTS
# save_dir: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets/RAW/ABIDE/Stanford_51171/Stanford_51171/anat/SNAPSHOTS
# file_path: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets/RAW/ABIDE/Stanford_51171/Stanford_51171/anat/SNAPSHOTS/downloaded_files.json
# Base dir: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets,
#  Subject name: RAW,
#  Entry name: ABIDE/Stanford_51171/Stanford_51171/rest/NIfTI
# save_dir: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets/RAW/ABIDE/Stanford_51171/Stanford_51171/rest/NIfTI
# file_path: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets/RAW/ABIDE/Stanford_51171/Stanford_51171/rest/NIfTI/downloaded_files.json
# Base dir: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets,
#  Subject name: RAW,
#  Entry name: ABIDE/Stanford_51171/Stanford_51171/rest/SNAPSHOTS
# save_dir: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets/RAW/ABIDE/Stanford_51171/Stanford_51171/rest/SNAPSHOTS
# file_path: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets/RAW/ABIDE/Stanford_51171/Stanford_51171/rest/SNAPSHOTS/downloaded_files.json
# Base dir: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets,
#  Subject name: RAW,
#  Entry name: ABIDE/Olin_50109/Olin_50109/anat/NIfTI
# save_dir: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets/RAW/ABIDE/Olin_50109/Olin_50109/anat/NIfTI
# file_path: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets/RAW/ABIDE/Olin_50109/Olin_50109/anat/NIfTI/downloaded_files.json
# Base dir: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets,
#  Subject name: RAW,
#  Entry name: ABIDE/Olin_50109/Olin_50109/anat/SNAPSHOTS
# save_dir: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets/RAW/ABIDE/Olin_50109/Olin_50109/anat/SNAPSHOTS
# file_path: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets/RAW/ABIDE/Olin_50109/Olin_50109/anat/SNAPSHOTS/downloaded_files.json
# Base dir: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets,
#  Subject name: RAW,
#  Entry name: ABIDE/Olin_50109/Olin_50109/rest/NIfTI
# save_dir: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets/RAW/ABIDE/Olin_50109/Olin_50109/rest/NIfTI
# file_path: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets/RAW/ABIDE/Olin_50109/Olin_50109/rest/NIfTI/downloaded_files.json
# Base dir: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets,
#  Subject name: RAW,
#  Entry name: ABIDE/Olin_50109/Olin_50109/rest/SNAPSHOTS
# save_dir: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets/RAW/ABIDE/Olin_50109/Olin_50109/rest/SNAPSHOTS
# file_path: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets/RAW/ABIDE/Olin_50109/Olin_50109/rest/SNAPSHOTS/downloaded_files.json
# Base dir: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets,
#  Subject name: RAW,
#  Entry name: ABIDE/Olin_50108/Olin_50108/anat/NIfTI
# save_dir: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets/RAW/ABIDE/Olin_50108/Olin_50108/anat/NIfTI
# file_path: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets/RAW/ABIDE/Olin_50108/Olin_50108/anat/NIfTI/downloaded_files.json
# Base dir: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets,
#  Subject name: RAW,
#  Entry name: ABIDE/Olin_50108/Olin_50108/anat/SNAPSHOTS
# save_dir: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets/RAW/ABIDE/Olin_50108/Olin_50108/anat/SNAPSHOTS
# file_path: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets/RAW/ABIDE/Olin_50108/Olin_50108/anat/SNAPSHOTS/downloaded_files.json
# Base dir: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets,
#  Subject name: RAW,
#  Entry name: ABIDE/Olin_50108/Olin_50108/rest/NIfTI
# save_dir: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets/RAW/ABIDE/Olin_50108/Olin_50108/rest/NIfTI
# file_path: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets/RAW/ABIDE/Olin_50108/Olin_50108/rest/NIfTI/downloaded_files.json
# Base dir: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets,
#  Subject name: RAW,
#  Entry name: ABIDE/Olin_50108/Olin_50108/rest/SNAPSHOTS
# save_dir: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets/RAW/ABIDE/Olin_50108/Olin_50108/rest/SNAPSHOTS
# file_path: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets/RAW/ABIDE/Olin_50108/Olin_50108/rest/SNAPSHOTS/downloaded_files.json
# Base dir: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets,
#  Subject name: RAW,
#  Entry name: ABIDE/Olin_50107/Olin_50107/anat/NIfTI
# save_dir: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets/RAW/ABIDE/Olin_50107/Olin_50107/anat/NIfTI
# file_path: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets/RAW/ABIDE/Olin_50107/Olin_50107/anat/NIfTI/downloaded_files.json
# Base dir: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets,
#  Subject name: RAW,
#  Entry name: ABIDE/Olin_50107/Olin_50107/anat/SNAPSHOTS
# save_dir: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets/RAW/ABIDE/Olin_50107/Olin_50107/anat/SNAPSHOTS
# file_path: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets/RAW/ABIDE/Olin_50107/Olin_50107/anat/SNAPSHOTS/downloaded_files.json
# Base dir: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets,
#  Subject name: RAW,
#  Entry name: ABIDE/Olin_50107/Olin_50107/rest/NIfTI
# save_dir: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets/RAW/ABIDE/Olin_50107/Olin_50107/rest/NIfTI
# file_path: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets/RAW/ABIDE/Olin_50107/Olin_50107/rest/NIfTI/downloaded_files.json
# Base dir: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets,
#  Subject name: RAW,
#  Entry name: ABIDE/Olin_50107/Olin_50107/rest/SNAPSHOTS
# save_dir: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets/RAW/ABIDE/Olin_50107/Olin_50107/rest/SNAPSHOTS
# file_path: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets/RAW/ABIDE/Olin_50107/Olin_50107/rest/SNAPSHOTS/downloaded_files.json
# Base dir: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets,
#  Subject name: RAW,
#  Entry name: ABIDE/Olin_50117/Olin_50117/anat/NIfTI
# save_dir: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets/RAW/ABIDE/Olin_50117/Olin_50117/anat/NIfTI
# file_path: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets/RAW/ABIDE/Olin_50117/Olin_50117/anat/NIfTI/downloaded_files.json
# Base dir: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets,
#  Subject name: RAW,
#  Entry name: ABIDE/Olin_50117/Olin_50117/anat/SNAPSHOTS
# save_dir: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets/RAW/ABIDE/Olin_50117/Olin_50117/anat/SNAPSHOTS
# file_path: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets/RAW/ABIDE/Olin_50117/Olin_50117/anat/SNAPSHOTS/downloaded_files.json
# Base dir: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets,
#  Subject name: RAW,
#  Entry name: ABIDE/Olin_50117/Olin_50117/rest/NIfTI
# save_dir: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets/RAW/ABIDE/Olin_50117/Olin_50117/rest/NIfTI
# file_path: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets/RAW/ABIDE/Olin_50117/Olin_50117/rest/NIfTI/downloaded_files.json
# Base dir: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets,
#  Subject name: RAW,
#  Entry name: ABIDE/Olin_50117/Olin_50117/rest/SNAPSHOTS
# save_dir: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets/RAW/ABIDE/Olin_50117/Olin_50117/rest/SNAPSHOTS
# file_path: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets/RAW/ABIDE/Olin_50117/Olin_50117/rest/SNAPSHOTS/downloaded_files.json
# Base dir: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets,
#  Subject name: RAW,
#  Entry name: ABIDE/USM_50498/USM_50498/anat/SNAPSHOTS
# save_dir: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets/RAW/ABIDE/USM_50498/USM_50498/anat/SNAPSHOTS
# file_path: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets/RAW/ABIDE/USM_50498/USM_50498/anat/SNAPSHOTS/downloaded_files.json
# Base dir: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets,
#  Subject name: RAW,
#  Entry name: ABIDE/USM_50498/USM_50498/anat/NIfTI
# save_dir: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets/RAW/ABIDE/USM_50498/USM_50498/anat/NIfTI
# file_path: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets/RAW/ABIDE/USM_50498/USM_50498/anat/NIfTI/downloaded_files.json
# Base dir: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets,
#  Subject name: RAW,
#  Entry name: ABIDE/USM_50498/USM_50498/rest/SNAPSHOTS
# save_dir: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets/RAW/ABIDE/USM_50498/USM_50498/rest/SNAPSHOTS
# file_path: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets/RAW/ABIDE/USM_50498/USM_50498/rest/SNAPSHOTS/downloaded_files.json
# Base dir: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets,
#  Subject name: RAW,
#  Entry name: ABIDE/USM_50498/USM_50498/rest/NIfTI
# save_dir: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets/RAW/ABIDE/USM_50498/USM_50498/rest/NIfTI
# file_path: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets/RAW/ABIDE/USM_50498/USM_50498/rest/NIfTI/downloaded_files.json
# Base dir: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets,
#  Subject name: RAW,
#  Entry name: ABIDE/NYU_50960/NYU_50960/anat/NIfTI
# save_dir: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets/RAW/ABIDE/NYU_50960/NYU_50960/anat/NIfTI
# file_path: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets/RAW/ABIDE/NYU_50960/NYU_50960/anat/NIfTI/downloaded_files.json
# Base dir: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets,
#  Subject name: RAW,
#  Entry name: ABIDE/NYU_50960/NYU_50960/anat/SNAPSHOTS
# save_dir: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets/RAW/ABIDE/NYU_50960/NYU_50960/anat/SNAPSHOTS
# file_path: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets/RAW/ABIDE/NYU_50960/NYU_50960/anat/SNAPSHOTS/downloaded_files.json
# Base dir: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets,
#  Subject name: RAW,
#  Entry name: ABIDE/NYU_50960/NYU_50960/rest/NIfTI
# save_dir: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets/RAW/ABIDE/NYU_50960/NYU_50960/rest/NIfTI
# file_path: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets/RAW/ABIDE/NYU_50960/NYU_50960/rest/NIfTI/downloaded_files.json
# Base dir: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets,
#  Subject name: RAW,
#  Entry name: ABIDE/NYU_50960/NYU_50960/rest/SNAPSHOTS
# save_dir: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets/RAW/ABIDE/NYU_50960/NYU_50960/rest/SNAPSHOTS
# file_path: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets/RAW/ABIDE/NYU_50960/NYU_50960/rest/SNAPSHOTS/downloaded_files.json
# Base dir: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets,
#  Subject name: RAW,
#  Entry name: ABIDE/Olin_50116/Olin_50116/anat/NIfTI
# save_dir: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets/RAW/ABIDE/Olin_50116/Olin_50116/anat/NIfTI
# file_path: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets/RAW/ABIDE/Olin_50116/Olin_50116/anat/NIfTI/downloaded_files.json
# Base dir: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets,
#  Subject name: RAW,
#  Entry name: ABIDE/Olin_50116/Olin_50116/anat/SNAPSHOTS
# save_dir: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets/RAW/ABIDE/Olin_50116/Olin_50116/anat/SNAPSHOTS
# file_path: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets/RAW/ABIDE/Olin_50116/Olin_50116/anat/SNAPSHOTS/downloaded_files.json
# Base dir: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets,
#  Subject name: RAW,
#  Entry name: ABIDE/Olin_50116/Olin_50116/rest/NIfTI
# save_dir: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets/RAW/ABIDE/Olin_50116/Olin_50116/rest/NIfTI
# file_path: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets/RAW/ABIDE/Olin_50116/Olin_50116/rest/NIfTI/downloaded_files.json
# Base dir: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets,
#  Subject name: RAW,
#  Entry name: ABIDE/Olin_50116/Olin_50116/rest/SNAPSHOTS
# save_dir: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets/RAW/ABIDE/Olin_50116/Olin_50116/rest/SNAPSHOTS
# file_path: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets/RAW/ABIDE/Olin_50116/Olin_50116/rest/SNAPSHOTS/downloaded_files.json
# Base dir: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets,
#  Subject name: RAW,
#  Entry name: ABIDE/USM_50499/USM_50499/anat/NIfTI
# save_dir: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets/RAW/ABIDE/USM_50499/USM_50499/anat/NIfTI
# file_path: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets/RAW/ABIDE/USM_50499/USM_50499/anat/NIfTI/downloaded_files.json
# Base dir: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets,
#  Subject name: RAW,
#  Entry name: ABIDE/USM_50499/USM_50499/anat/SNAPSHOTS
# save_dir: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets/RAW/ABIDE/USM_50499/USM_50499/anat/SNAPSHOTS
# file_path: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets/RAW/ABIDE/USM_50499/USM_50499/anat/SNAPSHOTS/downloaded_files.json
# Base dir: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets,
#  Subject name: RAW,
#  Entry name: ABIDE/USM_50499/USM_50499/rest/NIfTI
# save_dir: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets/RAW/ABIDE/USM_50499/USM_50499/rest/NIfTI
# file_path: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets/RAW/ABIDE/USM_50499/USM_50499/rest/NIfTI/downloaded_files.json
# Base dir: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets,
#  Subject name: RAW,
#  Entry name: ABIDE/USM_50499/USM_50499/rest/SNAPSHOTS
# save_dir: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets/RAW/ABIDE/USM_50499/USM_50499/rest/SNAPSHOTS
# file_path: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets/RAW/ABIDE/USM_50499/USM_50499/rest/SNAPSHOTS/downloaded_files.json
# Base dir: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets,
#  Subject name: RAW,
#  Entry name: ABIDE/Olin_50115/Olin_50115/anat/NIfTI
# save_dir: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets/RAW/ABIDE/Olin_50115/Olin_50115/anat/NIfTI
# file_path: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets/RAW/ABIDE/Olin_50115/Olin_50115/anat/NIfTI/downloaded_files.json
# Base dir: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets,
#  Subject name: RAW,
#  Entry name: ABIDE/Olin_50115/Olin_50115/anat/SNAPSHOTS
# save_dir: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets/RAW/ABIDE/Olin_50115/Olin_50115/anat/SNAPSHOTS
# file_path: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets/RAW/ABIDE/Olin_50115/Olin_50115/anat/SNAPSHOTS/downloaded_files.json
# Base dir: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets,
#  Subject name: RAW,
#  Entry name: ABIDE/Olin_50115/Olin_50115/rest/NIfTI
# save_dir: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets/RAW/ABIDE/Olin_50115/Olin_50115/rest/NIfTI
# file_path: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets/RAW/ABIDE/Olin_50115/Olin_50115/rest/NIfTI/downloaded_files.json
# Base dir: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets,
#  Subject name: RAW,
#  Entry name: ABIDE/Olin_50115/Olin_50115/rest/SNAPSHOTS
# save_dir: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets/RAW/ABIDE/Olin_50115/Olin_50115/rest/SNAPSHOTS
# file_path: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets/RAW/ABIDE/Olin_50115/Olin_50115/rest/SNAPSHOTS/downloaded_files.json
# Base dir: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets,
#  Subject name: RAW,
#  Entry name: ABIDE/Olin_50114/Olin_50114/anat/NIfTI
# save_dir: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets/RAW/ABIDE/Olin_50114/Olin_50114/anat/NIfTI
# file_path: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets/RAW/ABIDE/Olin_50114/Olin_50114/anat/NIfTI/downloaded_files.json
# Base dir: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets,
#  Subject name: RAW,
#  Entry name: ABIDE/Olin_50114/Olin_50114/anat/SNAPSHOTS
# save_dir: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets/RAW/ABIDE/Olin_50114/Olin_50114/anat/SNAPSHOTS
# file_path: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets/RAW/ABIDE/Olin_50114/Olin_50114/anat/SNAPSHOTS/downloaded_files.json
# Base dir: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets,
#  Subject name: RAW,
#  Entry name: ABIDE/Olin_50114/Olin_50114/rest/NIfTI
# save_dir: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets/RAW/ABIDE/Olin_50114/Olin_50114/rest/NIfTI
# file_path: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets/RAW/ABIDE/Olin_50114/Olin_50114/rest/NIfTI/downloaded_files.json
# Base dir: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets,
#  Subject name: RAW,
#  Entry name: ABIDE/Olin_50114/Olin_50114/rest/SNAPSHOTS
# save_dir: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets/RAW/ABIDE/Olin_50114/Olin_50114/rest/SNAPSHOTS
# file_path: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets/RAW/ABIDE/Olin_50114/Olin_50114/rest/SNAPSHOTS/downloaded_files.json
# Base dir: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets,
#  Subject name: RAW,
#  Entry name: ABIDE/Olin_50113/Olin_50113/anat/NIfTI
# save_dir: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets/RAW/ABIDE/Olin_50113/Olin_50113/anat/NIfTI
# file_path: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets/RAW/ABIDE/Olin_50113/Olin_50113/anat/NIfTI/downloaded_files.json
# Base dir: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets,
#  Subject name: RAW,
#  Entry name: ABIDE/Olin_50113/Olin_50113/anat/SNAPSHOTS
# save_dir: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets/RAW/ABIDE/Olin_50113/Olin_50113/anat/SNAPSHOTS
# file_path: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets/RAW/ABIDE/Olin_50113/Olin_50113/anat/SNAPSHOTS/downloaded_files.json
# Base dir: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets,
#  Subject name: RAW,
#  Entry name: ABIDE/Olin_50113/Olin_50113/rest/NIfTI
# save_dir: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets/RAW/ABIDE/Olin_50113/Olin_50113/rest/NIfTI
# file_path: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets/RAW/ABIDE/Olin_50113/Olin_50113/rest/NIfTI/downloaded_files.json
# Base dir: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets,
#  Subject name: RAW,
#  Entry name: ABIDE/Olin_50113/Olin_50113/rest/SNAPSHOTS
# save_dir: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets/RAW/ABIDE/Olin_50113/Olin_50113/rest/SNAPSHOTS
# file_path: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets/RAW/ABIDE/Olin_50113/Olin_50113/rest/SNAPSHOTS/downloaded_files.json
# Base dir: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets,
#  Subject name: RAW,
#  Entry name: ABIDE/NYU_50964/NYU_50964/anat/NIfTI
# save_dir: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets/RAW/ABIDE/NYU_50964/NYU_50964/anat/NIfTI
# file_path: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets/RAW/ABIDE/NYU_50964/NYU_50964/anat/NIfTI/downloaded_files.json
# Base dir: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets,
#  Subject name: RAW,
#  Entry name: ABIDE/NYU_50964/NYU_50964/anat/SNAPSHOTS
# save_dir: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets/RAW/ABIDE/NYU_50964/NYU_50964/anat/SNAPSHOTS
# file_path: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets/RAW/ABIDE/NYU_50964/NYU_50964/anat/SNAPSHOTS/downloaded_files.json
# Base dir: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets,
#  Subject name: RAW,
#  Entry name: ABIDE/NYU_50964/NYU_50964/rest/NIfTI
# save_dir: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets/RAW/ABIDE/NYU_50964/NYU_50964/rest/NIfTI
# file_path: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets/RAW/ABIDE/NYU_50964/NYU_50964/rest/NIfTI/downloaded_files.json
# Base dir: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets,
#  Subject name: RAW,
#  Entry name: ABIDE/NYU_50964/NYU_50964/rest/SNAPSHOTS
# save_dir: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets/RAW/ABIDE/NYU_50964/NYU_50964/rest/SNAPSHOTS
# file_path: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets/RAW/ABIDE/NYU_50964/NYU_50964/rest/SNAPSHOTS/downloaded_files.json
# Base dir: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets,
#  Subject name: RAW,
#  Entry name: ABIDE/Olin_50112/Olin_50112/anat/NIfTI
# save_dir: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets/RAW/ABIDE/Olin_50112/Olin_50112/anat/NIfTI
# file_path: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets/RAW/ABIDE/Olin_50112/Olin_50112/anat/NIfTI/downloaded_files.json
# Base dir: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets,
#  Subject name: RAW,
#  Entry name: ABIDE/Olin_50112/Olin_50112/anat/SNAPSHOTS
# save_dir: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets/RAW/ABIDE/Olin_50112/Olin_50112/anat/SNAPSHOTS
# file_path: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets/RAW/ABIDE/Olin_50112/Olin_50112/anat/SNAPSHOTS/downloaded_files.json
# Base dir: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets,
#  Subject name: RAW,
#  Entry name: ABIDE/Olin_50112/Olin_50112/rest/NIfTI
# save_dir: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets/RAW/ABIDE/Olin_50112/Olin_50112/rest/NIfTI
# file_path: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets/RAW/ABIDE/Olin_50112/Olin_50112/rest/NIfTI/downloaded_files.json
# Base dir: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets,
#  Subject name: RAW,
#  Entry name: ABIDE/Olin_50112/Olin_50112/rest/SNAPSHOTS
# save_dir: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets/RAW/ABIDE/Olin_50112/Olin_50112/rest/SNAPSHOTS
# file_path: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets/RAW/ABIDE/Olin_50112/Olin_50112/rest/SNAPSHOTS/downloaded_files.json
# Base dir: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets,
#  Subject name: RAW,
#  Entry name: ABIDE/NYU_50961/NYU_50961/anat/NIfTI
# save_dir: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets/RAW/ABIDE/NYU_50961/NYU_50961/anat/NIfTI
# file_path: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets/RAW/ABIDE/NYU_50961/NYU_50961/anat/NIfTI/downloaded_files.json
# Base dir: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets,
#  Subject name: RAW,
#  Entry name: ABIDE/NYU_50961/NYU_50961/anat/SNAPSHOTS
# save_dir: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets/RAW/ABIDE/NYU_50961/NYU_50961/anat/SNAPSHOTS
# file_path: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets/RAW/ABIDE/NYU_50961/NYU_50961/anat/SNAPSHOTS/downloaded_files.json
# Base dir: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets,
#  Subject name: RAW,
#  Entry name: ABIDE/NYU_50961/NYU_50961/rest/NIfTI
# save_dir: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets/RAW/ABIDE/NYU_50961/NYU_50961/rest/NIfTI
# file_path: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets/RAW/ABIDE/NYU_50961/NYU_50961/rest/NIfTI/downloaded_files.json
# Base dir: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets,
#  Subject name: RAW,
#  Entry name: ABIDE/NYU_50961/NYU_50961/rest/SNAPSHOTS
# save_dir: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets/RAW/ABIDE/NYU_50961/NYU_50961/rest/SNAPSHOTS
# file_path: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets/RAW/ABIDE/NYU_50961/NYU_50961/rest/SNAPSHOTS/downloaded_files.json
# Base dir: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets,
#  Subject name: RAW,
#  Entry name: ABIDE/Olin_50111/Olin_50111/anat/NIfTI
# save_dir: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets/RAW/ABIDE/Olin_50111/Olin_50111/anat/NIfTI
# file_path: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets/RAW/ABIDE/Olin_50111/Olin_50111/anat/NIfTI/downloaded_files.json
# Base dir: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets,
#  Subject name: RAW,
#  Entry name: ABIDE/Olin_50111/Olin_50111/anat/SNAPSHOTS
# save_dir: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets/RAW/ABIDE/Olin_50111/Olin_50111/anat/SNAPSHOTS
# file_path: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets/RAW/ABIDE/Olin_50111/Olin_50111/anat/SNAPSHOTS/downloaded_files.json
# Base dir: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets,
#  Subject name: RAW,
#  Entry name: ABIDE/Olin_50111/Olin_50111/rest/NIfTI
# save_dir: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets/RAW/ABIDE/Olin_50111/Olin_50111/rest/NIfTI
# file_path: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets/RAW/ABIDE/Olin_50111/Olin_50111/rest/NIfTI/downloaded_files.json
# Base dir: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets,
#  Subject name: RAW,
#  Entry name: ABIDE/Olin_50111/Olin_50111/rest/SNAPSHOTS
# save_dir: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets/RAW/ABIDE/Olin_50111/Olin_50111/rest/SNAPSHOTS
# file_path: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets/RAW/ABIDE/Olin_50111/Olin_50111/rest/SNAPSHOTS/downloaded_files.json
# Base dir: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets,
#  Subject name: RAW,
#  Entry name: ABIDE/NYU_50962/NYU_50962/anat/NIfTI
# save_dir: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets/RAW/ABIDE/NYU_50962/NYU_50962/anat/NIfTI
# file_path: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets/RAW/ABIDE/NYU_50962/NYU_50962/anat/NIfTI/downloaded_files.json
# Base dir: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets,
#  Subject name: RAW,
#  Entry name: ABIDE/NYU_50962/NYU_50962/anat/SNAPSHOTS
# save_dir: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets/RAW/ABIDE/NYU_50962/NYU_50962/anat/SNAPSHOTS
# file_path: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets/RAW/ABIDE/NYU_50962/NYU_50962/anat/SNAPSHOTS/downloaded_files.json
# Base dir: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets,
#  Subject name: RAW,
#  Entry name: ABIDE/NYU_50962/NYU_50962/rest/NIfTI
# save_dir: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets/RAW/ABIDE/NYU_50962/NYU_50962/rest/NIfTI
# file_path: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets/RAW/ABIDE/NYU_50962/NYU_50962/rest/NIfTI/downloaded_files.json
# Base dir: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets,
#  Subject name: RAW,
#  Entry name: ABIDE/NYU_50962/NYU_50962/rest/SNAPSHOTS
# save_dir: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets/RAW/ABIDE/NYU_50962/NYU_50962/rest/SNAPSHOTS
# file_path: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets/RAW/ABIDE/NYU_50962/NYU_50962/rest/SNAPSHOTS/downloaded_files.json
# Base dir: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets,
#  Subject name: RAW,
#  Entry name: ABIDE/Olin_50110/Olin_50110/anat/NIfTI
# save_dir: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets/RAW/ABIDE/Olin_50110/Olin_50110/anat/NIfTI
# file_path: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets/RAW/ABIDE/Olin_50110/Olin_50110/anat/NIfTI/downloaded_files.json
# Base dir: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets,
#  Subject name: RAW,
#  Entry name: ABIDE/Olin_50110/Olin_50110/anat/SNAPSHOTS
# save_dir: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets/RAW/ABIDE/Olin_50110/Olin_50110/anat/SNAPSHOTS
# file_path: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets/RAW/ABIDE/Olin_50110/Olin_50110/anat/SNAPSHOTS/downloaded_files.json
# Base dir: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets,
#  Subject name: RAW,
#  Entry name: ABIDE/Olin_50110/Olin_50110/rest/NIfTI
# save_dir: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets/RAW/ABIDE/Olin_50110/Olin_50110/rest/NIfTI
# file_path: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets/RAW/ABIDE/Olin_50110/Olin_50110/rest/NIfTI/downloaded_files.json
# Base dir: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets,
#  Subject name: RAW,
#  Entry name: ABIDE/Olin_50110/Olin_50110/rest/SNAPSHOTS
# save_dir: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets/RAW/ABIDE/Olin_50110/Olin_50110/rest/SNAPSHOTS
# file_path: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets/RAW/ABIDE/Olin_50110/Olin_50110/rest/SNAPSHOTS/downloaded_files.json
# Base dir: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets,
#  Subject name: RAW,
#  Entry name: ABIDE/NYU_50967/NYU_50967/anat/NIfTI
# save_dir: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets/RAW/ABIDE/NYU_50967/NYU_50967/anat/NIfTI
# file_path: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets/RAW/ABIDE/NYU_50967/NYU_50967/anat/NIfTI/downloaded_files.json
# Base dir: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets,
#  Subject name: RAW,
#  Entry name: ABIDE/NYU_50967/NYU_50967/anat/SNAPSHOTS
# save_dir: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets/RAW/ABIDE/NYU_50967/NYU_50967/anat/SNAPSHOTS
# file_path: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets/RAW/ABIDE/NYU_50967/NYU_50967/anat/SNAPSHOTS/downloaded_files.json
# Base dir: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets,
#  Subject name: RAW,
#  Entry name: ABIDE/NYU_50967/NYU_50967/rest/NIfTI
# save_dir: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets/RAW/ABIDE/NYU_50967/NYU_50967/rest/NIfTI
# file_path: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets/RAW/ABIDE/NYU_50967/NYU_50967/rest/NIfTI/downloaded_files.json
# Base dir: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets,
#  Subject name: RAW,
#  Entry name: ABIDE/NYU_50967/NYU_50967/rest/SNAPSHOTS
# save_dir: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets/RAW/ABIDE/NYU_50967/NYU_50967/rest/SNAPSHOTS
# file_path: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets/RAW/ABIDE/NYU_50967/NYU_50967/rest/SNAPSHOTS/downloaded_files.json
# Base dir: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets,
#  Subject name: RAW,
#  Entry name: ABIDE/USM_50490/USM_50490/anat/NIfTI
# save_dir: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets/RAW/ABIDE/USM_50490/USM_50490/anat/NIfTI
# file_path: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets/RAW/ABIDE/USM_50490/USM_50490/anat/NIfTI/downloaded_files.json
# ...
#  Entry name: ABIDE/SDSU_50194/SDSU_50194/anat/SNAPSHOTS
# save_dir: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets/RAW/ABIDE/SDSU_50194/SDSU_50194/anat/SNAPSHOTS
# file_path: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets/RAW/ABIDE/SDSU_50194/SDSU_50194/anat/SNAPSHOTS/downloaded_files.json
# Base dir: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets,
#  Subject name: RAW,
#  Entry name: ABIDE/SDSU_50194/SDSU_50194/rest/NIfTI
# save_dir: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets/RAW/ABIDE/SDSU_50194/SDSU_50194/rest/NIfTI
# file_path: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets/RAW/ABIDE/SDSU_50194/SDSU_50194/rest/NIfTI/downloaded_files.json
# Base dir: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets,
#  Subject name: RAW,
#  Entry name: ABIDE/SDSU_50194/SDSU_50194/rest/SNAPSHOTS
# save_dir: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets/RAW/ABIDE/SDSU_50194/SDSU_50194/rest/SNAPSHOTS
# file_path: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets/RAW/ABIDE/SDSU_50194/SDSU_50194/rest/SNAPSHOTS/downloaded_files.json
# Base dir: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets,
#  Subject name: RAW,
#  Entry name: ABIDE/SDSU_50191/SDSU_50191/anat/NIfTI
# save_dir: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets/RAW/ABIDE/SDSU_50191/SDSU_50191/anat/NIfTI
# file_path: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets/RAW/ABIDE/SDSU_50191/SDSU_50191/anat/NIfTI/downloaded_files.json
# Base dir: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets,
#  Subject name: RAW,
#  Entry name: ABIDE/SDSU_50191/SDSU_50191/anat/SNAPSHOTS
# save_dir: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets/RAW/ABIDE/SDSU_50191/SDSU_50191/anat/SNAPSHOTS
# file_path: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets/RAW/ABIDE/SDSU_50191/SDSU_50191/anat/SNAPSHOTS/downloaded_files.json
# Base dir: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets,
#  Subject name: RAW,
#  Entry name: ABIDE/SDSU_50191/SDSU_50191/rest/NIfTI
# save_dir: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets/RAW/ABIDE/SDSU_50191/SDSU_50191/rest/NIfTI
# file_path: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets/RAW/ABIDE/SDSU_50191/SDSU_50191/rest/NIfTI/downloaded_files.json
# Base dir: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets,
#  Subject name: RAW,
#  Entry name: ABIDE/SDSU_50191/SDSU_50191/rest/SNAPSHOTS
# save_dir: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets/RAW/ABIDE/SDSU_50191/SDSU_50191/rest/SNAPSHOTS
# file_path: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets/RAW/ABIDE/SDSU_50191/SDSU_50191/rest/SNAPSHOTS/downloaded_files.json
# Base dir: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets,
#  Subject name: RAW,
#  Entry name: ABIDE/SDSU_50192/SDSU_50192/anat/NIfTI
# save_dir: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets/RAW/ABIDE/SDSU_50192/SDSU_50192/anat/NIfTI
# file_path: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets/RAW/ABIDE/SDSU_50192/SDSU_50192/anat/NIfTI/downloaded_files.json
# Base dir: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets,
#  Subject name: RAW,
#  Entry name: ABIDE/SDSU_50192/SDSU_50192/anat/SNAPSHOTS
# save_dir: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets/RAW/ABIDE/SDSU_50192/SDSU_50192/anat/SNAPSHOTS
# file_path: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets/RAW/ABIDE/SDSU_50192/SDSU_50192/anat/SNAPSHOTS/downloaded_files.json
# Base dir: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets,
#  Subject name: RAW,
#  Entry name: ABIDE/SDSU_50192/SDSU_50192/rest/NIfTI
# save_dir: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets/RAW/ABIDE/SDSU_50192/SDSU_50192/rest/NIfTI
# file_path: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets/RAW/ABIDE/SDSU_50192/SDSU_50192/rest/NIfTI/downloaded_files.json
# Base dir: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets,
#  Subject name: RAW,
#  Entry name: ABIDE/SDSU_50192/SDSU_50192/rest/SNAPSHOTS
# save_dir: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets/RAW/ABIDE/SDSU_50192/SDSU_50192/rest/SNAPSHOTS
# file_path: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets/RAW/ABIDE/SDSU_50192/SDSU_50192/rest/SNAPSHOTS/downloaded_files.json
# Base dir: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets,
#  Subject name: RAW,
#  Entry name: ABIDE/SDSU_50190/SDSU_50190/anat/NIfTI
# save_dir: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets/RAW/ABIDE/SDSU_50190/SDSU_50190/anat/NIfTI
# file_path: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets/RAW/ABIDE/SDSU_50190/SDSU_50190/anat/NIfTI/downloaded_files.json
# Base dir: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets,
#  Subject name: RAW,
#  Entry name: ABIDE/SDSU_50190/SDSU_50190/anat/SNAPSHOTS
# save_dir: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets/RAW/ABIDE/SDSU_50190/SDSU_50190/anat/SNAPSHOTS
# file_path: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets/RAW/ABIDE/SDSU_50190/SDSU_50190/anat/SNAPSHOTS/downloaded_files.json
# Base dir: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets,
#  Subject name: RAW,
#  Entry name: ABIDE/SDSU_50190/SDSU_50190/rest/NIfTI
# save_dir: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets/RAW/ABIDE/SDSU_50190/SDSU_50190/rest/NIfTI
# file_path: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets/RAW/ABIDE/SDSU_50190/SDSU_50190/rest/NIfTI/downloaded_files.json
# Base dir: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets,
#  Subject name: RAW,
#  Entry name: ABIDE/SDSU_50190/SDSU_50190/rest/SNAPSHOTS
# save_dir: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets/RAW/ABIDE/SDSU_50190/SDSU_50190/rest/SNAPSHOTS
# file_path: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets/RAW/ABIDE/SDSU_50190/SDSU_50190/rest/SNAPSHOTS/downloaded_files.json
# Base dir: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets,
#  Subject name: RAW,
#  Entry name: ABIDE/NYU_51155/NYU_51155/anat/NIfTI
# save_dir: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets/RAW/ABIDE/NYU_51155/NYU_51155/anat/NIfTI
# file_path: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets/RAW/ABIDE/NYU_51155/NYU_51155/anat/NIfTI/downloaded_files.json
# Base dir: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets,
#  Subject name: RAW,
#  Entry name: ABIDE/NYU_51155/NYU_51155/anat/SNAPSHOTS
# save_dir: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets/RAW/ABIDE/NYU_51155/NYU_51155/anat/SNAPSHOTS
# file_path: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets/RAW/ABIDE/NYU_51155/NYU_51155/anat/SNAPSHOTS/downloaded_files.json
# Base dir: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets,
#  Subject name: RAW,
#  Entry name: ABIDE/NYU_51155/NYU_51155/rest/NIfTI
# save_dir: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets/RAW/ABIDE/NYU_51155/NYU_51155/rest/NIfTI
# file_path: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets/RAW/ABIDE/NYU_51155/NYU_51155/rest/NIfTI/downloaded_files.json
# Base dir: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets,
#  Subject name: RAW,
#  Entry name: ABIDE/NYU_51155/NYU_51155/rest/SNAPSHOTS
# save_dir: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets/RAW/ABIDE/NYU_51155/NYU_51155/rest/SNAPSHOTS
# file_path: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets/RAW/ABIDE/NYU_51155/NYU_51155/rest/SNAPSHOTS/downloaded_files.json
# Base dir: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets,
#  Subject name: RAW,
#  Entry name: ABIDE/NYU_51156/NYU_51156/anat/NIfTI
# save_dir: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets/RAW/ABIDE/NYU_51156/NYU_51156/anat/NIfTI
# file_path: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets/RAW/ABIDE/NYU_51156/NYU_51156/anat/NIfTI/downloaded_files.json
# Base dir: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets,
#  Subject name: RAW,
#  Entry name: ABIDE/NYU_51156/NYU_51156/anat/SNAPSHOTS
# save_dir: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets/RAW/ABIDE/NYU_51156/NYU_51156/anat/SNAPSHOTS
# file_path: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets/RAW/ABIDE/NYU_51156/NYU_51156/anat/SNAPSHOTS/downloaded_files.json
# Base dir: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets,
#  Subject name: RAW,
#  Entry name: ABIDE/NYU_51156/NYU_51156/rest/NIfTI
# save_dir: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets/RAW/ABIDE/NYU_51156/NYU_51156/rest/NIfTI
# file_path: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets/RAW/ABIDE/NYU_51156/NYU_51156/rest/NIfTI/downloaded_files.json
# Base dir: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets,
#  Subject name: RAW,
#  Entry name: ABIDE/NYU_51156/NYU_51156/rest/SNAPSHOTS
# save_dir: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets/RAW/ABIDE/NYU_51156/NYU_51156/rest/SNAPSHOTS
# file_path: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets/RAW/ABIDE/NYU_51156/NYU_51156/rest/SNAPSHOTS/downloaded_files.json
# Base dir: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets,
#  Subject name: RAW,
#  Entry name: ABIDE/NYU_51159/NYU_51159/anat/NIfTI
# save_dir: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets/RAW/ABIDE/NYU_51159/NYU_51159/anat/NIfTI
# file_path: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets/RAW/ABIDE/NYU_51159/NYU_51159/anat/NIfTI/downloaded_files.json
# Base dir: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets,
#  Subject name: RAW,
#  Entry name: ABIDE/NYU_51159/NYU_51159/anat/SNAPSHOTS
# save_dir: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets/RAW/ABIDE/NYU_51159/NYU_51159/anat/SNAPSHOTS
# file_path: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets/RAW/ABIDE/NYU_51159/NYU_51159/anat/SNAPSHOTS/downloaded_files.json
# Base dir: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets,
#  Subject name: RAW,
#  Entry name: ABIDE/NYU_51159/NYU_51159/rest/NIfTI
# save_dir: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets/RAW/ABIDE/NYU_51159/NYU_51159/rest/NIfTI
# file_path: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets/RAW/ABIDE/NYU_51159/NYU_51159/rest/NIfTI/downloaded_files.json
# Base dir: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets,
#  Subject name: RAW,
#  Entry name: ABIDE/NYU_51159/NYU_51159/rest/SNAPSHOTS
# save_dir: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets/RAW/ABIDE/NYU_51159/NYU_51159/rest/SNAPSHOTS
# file_path: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets/RAW/ABIDE/NYU_51159/NYU_51159/rest/SNAPSHOTS/downloaded_files.json
# Base dir: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets,
#  Subject name: RAW,
#  Entry name: ABIDE/NYU_51150/NYU_51150/anat/NIfTI
# save_dir: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets/RAW/ABIDE/NYU_51150/NYU_51150/anat/NIfTI
# file_path: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets/RAW/ABIDE/NYU_51150/NYU_51150/anat/NIfTI/downloaded_files.json
# Base dir: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets,
#  Subject name: RAW,
#  Entry name: ABIDE/NYU_51150/NYU_51150/anat/SNAPSHOTS
# save_dir: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets/RAW/ABIDE/NYU_51150/NYU_51150/anat/SNAPSHOTS
# file_path: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets/RAW/ABIDE/NYU_51150/NYU_51150/anat/SNAPSHOTS/downloaded_files.json
# Base dir: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets,
#  Subject name: RAW,
#  Entry name: ABIDE/NYU_51150/NYU_51150/rest/NIfTI
# save_dir: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets/RAW/ABIDE/NYU_51150/NYU_51150/rest/NIfTI
# file_path: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets/RAW/ABIDE/NYU_51150/NYU_51150/rest/NIfTI/downloaded_files.json
# Base dir: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets,
#  Subject name: RAW,
#  Entry name: ABIDE/NYU_51150/NYU_51150/rest/SNAPSHOTS
# save_dir: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets/RAW/ABIDE/NYU_51150/NYU_51150/rest/SNAPSHOTS
# file_path: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets/RAW/ABIDE/NYU_51150/NYU_51150/rest/SNAPSHOTS/downloaded_files.json
# Base dir: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets,
#  Subject name: RAW,
#  Entry name: ABIDE/NYU_51153/NYU_51153/anat/NIfTI
# save_dir: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets/RAW/ABIDE/NYU_51153/NYU_51153/anat/NIfTI
# file_path: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets/RAW/ABIDE/NYU_51153/NYU_51153/anat/NIfTI/downloaded_files.json
# Base dir: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets,
#  Subject name: RAW,
#  Entry name: ABIDE/NYU_51153/NYU_51153/anat/SNAPSHOTS
# save_dir: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets/RAW/ABIDE/NYU_51153/NYU_51153/anat/SNAPSHOTS
# file_path: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets/RAW/ABIDE/NYU_51153/NYU_51153/anat/SNAPSHOTS/downloaded_files.json
# Base dir: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets,
#  Subject name: RAW,
#  Entry name: ABIDE/NYU_51153/NYU_51153/rest/NIfTI
# save_dir: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets/RAW/ABIDE/NYU_51153/NYU_51153/rest/NIfTI
# file_path: /workspaces/ASD-Diagnostic_Research_2023-24/ABIDE I/downloaded_fmri_datasets/RAW/ABIDE/NYU_51153/NYU_51153/rest/NIfTI/downloaded_files.json
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[11], line 57
#      54 file_path = os.path.join(save_dir, file_name)
#      55 print(f"file_path: {file_path}")
# ---> 57 with open(file_path, 'wb') as file:
#      58     for chunk in response.iter_content(chunk_size=128):
#      59         file.write(chunk)
#
# File ~/.local/lib/python3.10/site-packages/IPython/core/interactiveshell.py:308, in _modified_open(file, *args, **kwargs)
#     301 if file in {0, 1, 2}:
#     302     raise ValueError(
#     303         f"IPython won't let you open fd={file} by default "
#     304         "as it is likely to crash IPython. If you know what you are doing, "
#     305         "you can use builtins' open."
#     306     )
# --> 308 return io_open(file, *args, **kwargs)
#
# KeyboardInterrupt:
